# %% [markdown]
# <a href="https://colab.research.google.com/github/nanmaharaj/my-deeplearning-projects/blob/main/mobilenet_v2_transfer_learning(not_done).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE=(224,224)

classifier=tf.keras.Sequential([
    hub.KerasLayer("https://www.kaggle.com/models/google/mobilenet-v2/frameworks/tensorFlow2/variations/tf2-preview-classification/versions/4?tfhub-redirect=true",input_shape=IMAGE_SHAPE+(3,))
])

# %%
gold_fish=Image.open('goldfish.jpg').resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
gold_fish=np.array(gold_fish)/255.0
gold_fish[0]
# Out:
# array([[4.34222132e-06, 5.12623350e-06, 1.08555533e-06],
#        [4.82469035e-06, 5.72931979e-06, 1.38709848e-06],
#        [5.36746802e-06, 6.45302335e-06, 1.80925888e-06],
#        [5.60870254e-06, 6.99580101e-06, 1.99018477e-06],
#        [5.84993705e-06, 7.53857868e-06, 2.41234518e-06],
#        [5.91024568e-06, 7.90043045e-06, 2.65357969e-06],
#        [5.84993705e-06, 7.96073908e-06, 2.65357969e-06],
#        [5.72931979e-06, 7.96073908e-06, 2.53296244e-06],
#        [5.60870254e-06, 8.02104771e-06, 2.41234518e-06],
#        [5.54839391e-06, 8.02104771e-06, 2.53296244e-06],
#        [5.54839391e-06, 7.77981319e-06, 2.59327106e-06],
#        [5.48808528e-06, 7.53857868e-06, 2.65357969e-06],
#        [5.30715939e-06, 7.17672690e-06, 2.59327106e-06],
#        [5.30715939e-06, 7.11641827e-06, 2.83450558e-06],
#        [5.36746802e-06, 7.11641827e-06, 3.13604873e-06],
#        [5.42777665e-06, 7.05610964e-06, 3.13604873e-06],
# ...

# %%
gold_fish[np.newaxis, ...].shape
# Out:
# (1, 224, 224, 3)

# %%
result=classifier.predict(gold_fish[np.newaxis, ...])
print(result)

predicted_label_index=np.argmax(result)
print(predicted_label_index)
# Out:
# 1/1 [==============================] - 0s 61ms/step
# [[-0.18002093 -0.40603995  0.8190509  ... -0.895339   -1.0841329
#    1.2913574 ]]
# 819
